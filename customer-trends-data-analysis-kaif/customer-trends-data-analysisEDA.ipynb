# %% [markdown]
# ## Exploratory Data Analysis using Python

# %%
import pandas as pd

df = pd.read_csv('customer_shopping_behavior.csv')

# %%
df.sample(10)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 1207         1208   62    Male          Boots     Footwear
# 3025         3026   40  Female          Shoes     Footwear
# 1578         1579   62    Male          Pants     Clothing
# 2780         2781   33  Female          Boots     Footwear
# 2529         2530   34    Male         Gloves  Accessories
# 3844         3845   30  Female         Shorts     Clothing
# 2784         2785   33  Female          Skirt     Clothing
# 1724         1725   42    Male          Shoes     Footwear
# 1093         1094   60    Male       Sneakers     Footwear
# 2599         2600   63    Male        Jewelry  Accessories
#
#       Purchase Amount (USD)    Location Size     Color  Season  Review Rating  \
# 1207                     90  Washington    M     White  Summer            4.1
# 3025                     60     Montana   XL     Green  Summer            3.4
# 1578                     97  California    S    Maroon  Winter            4.9
# 2780                     70        Ohio    M  Charcoal  Winter            4.1
# 2529                     62   Tennessee    M   Magenta  Spring            4.7
# 3844                     87     Montana    S      Cyan    Fall            5.0
# 2784                     70       Idaho    M     Black  Winter            3.1
# 1724                     72    Delaware    S      Teal  Winter            3.3
# 1093                     48    Delaware    S    Indigo  Winter            4.2
# 2599                     99     Vermont    M      Gold  Winter            3.4
#
#      Subscription Status   Shipping Type Discount Applied Promo Code Used  \
# 1207                  No    Next Day Air              Yes             Yes
# 3025                  No    Store Pickup               No              No
# 1578                  No  2-Day Shipping              Yes             Yes
# 2780                  No    Next Day Air               No              No
# 2529                  No    Next Day Air               No              No
# 3844                  No    Next Day Air               No              No
# 2784                  No         Express               No              No
# 1724                  No   Free Shipping               No              No
# 1093                  No  2-Day Shipping              Yes             Yes
# 2599                  No         Express               No              No
#
#       Previous Purchases Payment Method Frequency of Purchases
# 1207                  48    Credit Card         Every 3 Months
# 3025                   7         PayPal                Monthly
# 1578                   2         PayPal              Quarterly
# 2780                  29         PayPal            Fortnightly
# 2529                  48  Bank Transfer                Monthly
# 3844                  40          Venmo              Quarterly
# 2784                  12         PayPal         Every 3 Months
# 1724                  21         PayPal                 Weekly
# 1093                  46          Venmo         Every 3 Months
# 2599                  48    Credit Card                Monthly

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
#  14  Promo Code Used         3900 non-null   object
#  15  Previous Purchases      3900 non-null   int64
#  16  Payment Method          3900 non-null   object
#  17  Frequency of Purchases  3900 non-null   object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 548.6+ KB

# %%
df.describe(include='all')
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# unique                    NaN       50     4     25       4            NaN
# top                       NaN  Montana     M  Olive  Spring            NaN
# freq                      NaN       96  1755    177     999            NaN
# mean                59.764359      NaN   NaN    NaN     NaN       3.750065
# std                 23.685392      NaN   NaN    NaN     NaN       0.716983
# min                 20.000000      NaN   NaN    NaN     NaN       2.500000
# 25%                 39.000000      NaN   NaN    NaN     NaN       3.100000
# 50%                 60.000000      NaN   NaN    NaN     NaN       3.800000
# 75%                 81.000000      NaN   NaN    NaN     NaN       4.400000
# max                100.000000      NaN   NaN    NaN     NaN       5.000000
#
#        Subscription Status  Shipping Type Discount Applied Promo Code Used  \
# count                 3900           3900             3900            3900
# unique                   2              6                2               2
# top                     No  Free Shipping               No              No
# freq                  2847            675             2223            2223
# mean                   NaN            NaN              NaN             NaN
# std                    NaN            NaN              NaN             NaN
# min                    NaN            NaN              NaN             NaN
# 25%                    NaN            NaN              NaN             NaN
# 50%                    NaN            NaN              NaN             NaN
# 75%                    NaN            NaN              NaN             NaN
# max                    NaN            NaN              NaN             NaN
#
#         Previous Purchases Payment Method Frequency of Purchases
# count          3900.000000           3900                   3900
# unique                 NaN              6                      7
# top                    NaN         PayPal         Every 3 Months
# freq                   NaN            677                    584
# mean             25.351538            NaN                    NaN
# std              14.447125            NaN                    NaN
# min               1.000000            NaN                    NaN
# 25%              13.000000            NaN                    NaN
# 50%              25.000000            NaN                    NaN
# 75%              38.000000            NaN                    NaN
# max              50.000000            NaN                    NaN

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df['Review Rating']=df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %% [markdown]
# #### Put all col name in snake casing

# %%
df.columns = df.columns.str.lower()

df.columns = df.columns.str.replace(' ','_')

df = df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
# Create a new column age_group

labels  = ['Young Adult','Adult','Middle-aged','Senior']
df['age_group'] = pd.qcut(df['age'],q=4,labels=  labels)

# %%
df[['age','age_group']].sample(10)
# Out:
#       age    age_group
# 1340   40        Adult
# 3278   59       Senior
# 803    32        Adult
# 1155   67       Senior
# 2333   33        Adult
# 3154   27  Young Adult
# 2383   53  Middle-aged
# 1715   23  Young Adult
# 1567   30  Young Adult
# 197    59       Senior

# %%
# Create column purchase_frequency_days

frequency_mapping =  {
    'Fortnightly': 14,
    'Weekly': 7,
    'Monthly': 30,
    'Quarterly': 90,
    'Bi-Weekly': 14,
    'Annually': 365,
    'Every 3 Months':  90
}

df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['purchase_frequency_days','frequency_of_purchases']].head(10)
# Out:
#    purchase_frequency_days frequency_of_purchases
# 0                       14            Fortnightly
# 1                       14            Fortnightly
# 2                        7                 Weekly
# 3                        7                 Weekly
# 4                      365               Annually
# 5                        7                 Weekly
# 6                       90              Quarterly
# 7                        7                 Weekly
# 8                      365               Annually
# 9                       90              Quarterly

# %%
df = df.drop('promo_code_used',axis= 1)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'purchase_frequency_days'],
#       dtype='object')

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.11-cp313-cp313-win_amd64.whl.metadata (5.1 kB)
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.46-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.3.2-cp313-cp313-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\kaif firoz\anaconda3\envs\kaifs_python_project\lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading psycopg2_binary-2.9.11-cp313-cp313-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 3.1 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.7 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.7 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 4.1 MB/s  0:00:00
# Downloading sqlalchemy-2.0.46-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------------ --------------- 1.3/2.1 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 5.8 MB/s  0:00:00
# Downloading greenlet-3.3.2-cp313-cp313-win_amd64.whl (230 kB)
# Installing collected packages: psycopg2-binary, greenlet, sqlalchemy
#
#    ---------------------------------------- 0/3 [psycopg2-binary]
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    ---------------------------------------- 3/3 [sqlalchemy]
#
# Successfully installed greenlet-3.3.2 psycopg2-binary-2.9.11 sqlalchemy-2.0.46
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.6.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Downloading mysql_connector_python-9.6.0-cp313-cp313-win_amd64.whl (16.5 MB)
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.5 MB ? eta -:--:--
#    - -------------------------------------- 0.8/16.5 MB 2.8 MB/s eta 0:00:06
#    --- ------------------------------------ 1.6/16.5 MB 2.9 MB/s eta 0:00:06
#    ------ --------------------------------- 2.6/16.5 MB 3.4 MB/s eta 0:00:05
#    -------- ------------------------------- 3.7/16.5 MB 3.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 4.7/16.5 MB 4.0 MB/s eta 0:00:03
#    --------------- ------------------------ 6.3/16.5 MB 4.5 MB/s eta 0:00:03
#    ------------------ --------------------- 7.6/16.5 MB 4.7 MB/s eta 0:00:02
#    --------------------- ------------------ 8.9/16.5 MB 4.9 MB/s eta 0:00:02
#    ------------------------- -------------- 10.5/16.5 MB 5.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 12.1/16.5 MB 5.4 MB/s eta 0:00:01
#    --------------------------------- ------ 13.6/16.5 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------ --- 15.2/16.5 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 16.5/16.5 MB 5.8 MB/s  0:00:02
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

database = "customer_behaviour"

engine = create_engine(
    f"mysql+mysqlconnector://root:MYSQL1633@localhost/{database}"
)

table_name = "customer"

df.to_sql(table_name, engine, if_exists='replace', index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'customer' in database 'customer_behaviour'.
